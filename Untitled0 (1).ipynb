# %% [markdown]
# exp 0 : introduction to python

# %%
# Medhansh - 25070123074
print("medhansh gupta")
# Out:
# medhansh gupta

# %%
print(2)
# Out:
# 2

# %%
print([1,2,5])
# Out:
# [1, 2, 5]

# %%
x = 2
y = [1,2,5]
z = "medhansh gupta"
print(x,y,z,sep="\n")
# Out:
# 2
# [1, 2, 5]
# medhansh gupta
